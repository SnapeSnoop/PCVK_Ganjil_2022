# %% [markdown]
# <a href="https://colab.research.google.com/github/SnapeSnoop/PCVK_Ganjil_2022/blob/main/week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pylab as plt
import numpy as np

# %%
print('Mengubah tingkat kecerahan citra')
print('--------------------------------')
try:
  brightness = int(input('Masukan nilai kecerahan: '))
except ValueError:
    print('Error,not a number')

original = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(original[y,x,c] + brightness, 0, 255)
                                    
final_frame = cv.hconcat((original, brightness_image))
cv2_imshow(final_frame)
# Out:
# Mengubah tingkat kecerahan citra
# --------------------------------
# Masukan nilai kecerahan: 50
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FEB283495D0>

# %%
print('Mengubah tingkat kecerahan citra')
print('--------------------------------')
try:
  brightness = int(input('Masukan nilai kecerahan: '))
  kontras = float(input('Masukan Kontras: '))
except ValueError:
    print('Error,not a number')

original = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(kontras * original[y,x,c] + brightness,0,225)
                                    
final_frame = cv.hconcat((original, brightness_image))
cv2_imshow(final_frame)
# Out:
# Mengubah tingkat kecerahan citra
# --------------------------------
# Masukan nilai kecerahan: 60
# Masukan Kontras: 1.5
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FEB27658650>

# %%
print('Mengubah tingkat kecerahan citra')
print('--------------------------------')
try:
  brightness = int(input('Masukan nilai kecerahan: '))
except ValueError:
    print('Error,not a number')

original = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/female.tiff')
def logTransform(c, f):

    g = c * np.log(float(1 + f),10);

    return g;

def logTransformImage(image, outputMax = 255, inputMax = brightness):

    c = outputMax/np.log(inputMax + 1,10);

   

    # Read pixels and apply logarithmic transformation

    for i in range(0, original.size[0]-1):

        for j in range(0, original.size[1]-1):

            # Get pixel value at (x,y) position of the image

            f = original.getpixel((i,j));

           

            # Do log transformation of the pixel

            redPixel    = round(logTransform(c, f[0]));

            greenPixel  = round(logTransform(c, f[1]));

            bluePixel   = round(logTransform(c, f[2]));

 

            # Modify the image with the transformed pixel values

            original.putpixel((i,j),(redPixel, greenPixel, bluePixel));

 

    return image;

logTransformedImage = logTransformImage(original);                                   
final_frame = cv.hconcat((original, logTransformedImage))
cv2_imshow(final_frame)
# Out:
# Mengubah tingkat kecerahan citra
# --------------------------------
# Masukan nilai kecerahan: 60
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-3ff879d552b7> in <module>()
#      49     return image;
#      50
# ---> 51 logTransformedImage = logTransformImage(original);
#      52 final_frame = cv.hconcat((original, logTransformedImage))
#      53 cv2_imshow(final_frame)
#
# <ipython-input-72-3ff879d552b7> in logTransformImage(image, outputMax, inputMax)
#      15 def logTransformImage(image, outputMax = 255, inputMax = brightness):
#      16
# ---> 17     c = outputMax/np.log(inputMax + 1,10);
#      18
#      19
#
# TypeError: return arrays must be of ArrayType

# %%
color_img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/mandrill.tiff')

R, G, B = color_img[:,:,0],color_img[:,:,1],color_img[:,:,2]
max_channels = np.maximum(np.maximum(R, G),B)
min_channels = np.minimum(np.minimum(R, G),B)

gray_img = max_channels/2 + min_channels/2

f, axarr = plt.subplots(1,2)
axarr[0].imshow(color_img)
axarr[1].imshow(gray_img,cmap='gray')

# %%
color_img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/mandrill.tiff')

R, G, B = color_img[:,:,0],color_img[:,:,1],color_img[:,:,2]

gray_img = (0.2126 * R) + (0.7152 * G) + (0.0722 * B)

f, axarr = plt.subplots(1,2)
axarr[0].imshow(color_img)
axarr[1].imshow(gray_img,cmap='gray')

# %%
color_img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/mandrill.tiff')

R, G, B = color_img[:,:,0],color_img[:,:,1],color_img[:,:,2]
max_channels = np.maximum(np.maximum(R, G),B)

gray_img = max_channels/2 + min_channels/1

f, axarr = plt.subplots(1,2)
axarr[0].imshow(color_img)
axarr[1].imshow(gray_img,cmap='gray')
