# %% [markdown]
# <a href="https://colab.research.google.com/github/SnapeSnoop/PCVK_Ganjil_2022/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
#Create list for save url from image

urls = ["https://placekitten.com/200/300"]

for url in urls:
  image = io.imread(url)                          # read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) # resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  # convert color to RGB
  final_frame = cv.hconcat((image,image_2))       # concatenate iamge/get image
  cv2_imshow(final_frame)                         # show image display from import 
  print('\n')

  tinggi = image_2.shape[0]
  lebar = image_2.shape[1]
  print("resolusi image: tinggi x lebar =", tinggi, "x", lebar)
  cv2_imshow(image_2)
  

  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  image_5 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

  #craate horizotal line on center image

  for y in range (lebar):
   image_3[int((tinggi)/2),y] = [255,255,255]

  for x in range (lebar):
    image_4[int((tinggi)/2),x, ymin=0.25, ymax=0.75] = [255,255,255]

  for x in range (lebar):
    image_5[int((tinggi)/2),x] = [255,255,255]


  final_frame = cv.hconcat((image_2, image_3))
  cv2_imshow(final_frame)

  final_frame = cv.hconcat((image_2, image_4))
  cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=200x150 at 0x7FF7EAA64650>
# resolusi image: tinggi x lebar = 150 x 100
# <PIL.Image.Image image mode=RGB size=100x150 at 0x7FF7EAA60690>
# <PIL.Image.Image image mode=RGB size=200x150 at 0x7FF7EAA8DC10>
# <PIL.Image.Image image mode=RGB size=200x150 at 0x7FF7EC2F91D0>
